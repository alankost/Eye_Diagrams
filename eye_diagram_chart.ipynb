# %%
# %run bandwidth_jitter_chart.ipynb
# %run load_modules.ipynb
import ipywidgets as widgets
from IPython.display import display
pn.extension()
from bokeh.models import Range1d
trace_button = pn.widgets.Button(name="Trace",button_type='primary')
reset_button = pn.widgets.Button(name="Reset",button_type='primary')
# trace_button.style.button_color = 'lightgreen'; reset_button.style.button_color = 'lightgreen'

# display(HBox([trace_button, reset_button]))
# buttons = widgets.HBox([trace_button, reset_button])

Pave3 = Pave_slider2.value*1e-6
Threshold3 = Pave3*R*RL*G
bandwidth3 = bandwidth_slider.value
jitter_value = jitter_slider.value
for_std0=np.array([])
for_mean1=np.array([])
BER3=0

def find_parameters():
    global BER3
    global Pave3
    global bandwidth3
    global Threshold3
    global jitter_value
    Pave3 = Pave_slider2.value*1e-6
    bandwidth3 = bandwidth_slider.value
    jitter_value = jitter_slider.value
    Threshold3 = Pave3*R*RL*G
    for_std0=[]
    for_mean1=[]
    for i in range(1000):        
        ran_int1 = np.random.randint(0, 2)
        ran_int2 = np.random.randint(0, 2)
        ran_int3 = np.random.randint(0, 2)
        v13 = np.random.normal(ran_int1*Pave3*2*R*RL*G, sigmaT*RL, 400)
        v23 = np.random.normal(ran_int2*Pave3*2*R*RL*G, sigmaT*RL, 400)
        v33 = np.random.normal(ran_int3*Pave3*2*R*RL*G, sigmaT*RL, 400)
        v32 = np.concatenate([v13,v23,v33])
        shift = int(np.random.normal(jitter_value))
        v32=np.roll(v32,int(shift))
        sig_fft= np.fft.rfft(v32)
        fft_freq = np.linspace(0,600/1.200,601)
        filter=np.heaviside(bandwidth3-fft_freq,1)
        sig_fft_f = sig_fft*filter
        vf3=np.fft.irfft(sig_fft_f)        
        if ran_int2 == 0:
            for_std0=np.append(for_std0,vf3[600])
        if ran_int2 == 1:
            for_mean1=np.append(for_mean1,vf3[600])
    Q3 = np.mean(for_mean1)/(2*np.std(for_std0))
    BER3 =  0.5*special.erfc(Q3/np.sqrt(2))


v13 = np.random.normal(0, sigmaT*RL, 400)
v23 = np.random.normal(Pave3*2*R*RL*G, sigmaT*RL, 400)
v33 = np.random.normal(0, sigmaT*RL, 400)
v3 = np.concatenate([v13,v23,v33])
t=np.linspace(0,1200,1200) # time in picoseconds
zeros=np.zeros(1200)

sig_fft= np.fft.rfft(v3)
fft_freq = np.linspace(0,600/1.200,601)
filter=np.heaviside(bandwidth_slider.value-fft_freq,1)
sig_fft_f = sig_fft*filter
vf3=np.fft.irfft(sig_fft_f)
    
p4 = figure(width=400, height=400, background_fill_color="lightgray")
p4.title.text_font_style='normal'; p4.title.text_font_size='12pt'
p4.outline_line_width = 1; p4.outline_line_color = "black"; p4.min_border_top = 10
p4.x_range = Range1d(200, 1000); p4.y_range = Range1d(-0.1, 0.4)

eye0=p4.line(t,zeros,line_color='#2222aa')
eye1=p4.line(t,zeros,line_color='#2222aa')
eye2=p4.line(t,zeros,line_color='#2222aa')
eye3=p4.line(t,zeros,line_color='#2222aa')
eye4=p4.line(t,zeros,line_color='#2222aa')
eye5=p4.line(t,zeros,line_color='#2222aa')
eye6=p4.line(t,zeros,line_color='#2222aa')
eye7=p4.line(t,zeros,line_color='#2222aa')
eye8=p4.line(t,zeros,line_color='#2222aa')
eye9=p4.line(t,zeros,line_color='#2222aa')
eye10=p4.line(t,zeros,line_color='#2222aa')
eye11=p4.line(t,zeros,line_color='#2222aa')
eye12=p4.line(t,zeros,line_color='#2222aa')
eye13=p4.line(t,zeros,line_color='#2222aa')
eye14=p4.line(t,zeros,line_color='#2222aa')
eye15=p4.line(t,zeros,line_color='#2222aa')
eye16=p4.line(t,zeros,line_color='#2222aa')
eye17=p4.line(t,zeros,line_color='#2222aa')
eye18=p4.line(t,zeros,line_color='#2222aa')
eye19=p4.line(t,zeros,line_color='#2222aa')
eye20=p4.line(t,zeros,line_color='#2222aa')

eyes=([eye0,eye1,eye2, eye3,eye4,eye5,eye6,eye7,eye8,eye9,eye10,eye11,
      eye12,eye13,eye14,eye15,eye16,eye17,eye18,eye19,eye20])

thresh_line = p4.line(t,Threshold3+zeros,line_dash='dashed',line_color='red')
p4.xaxis.axis_label="Time (psec)"; p4.xaxis.major_label_text_font_size = "12pt"
p4.xaxis.axis_label_text_font_style = "normal"; p4.xaxis.axis_label_text_font_size = "12pt"
p4.yaxis.axis_label="Signal (arb. units)"; p4.yaxis.major_label_text_font_size = "12pt"
p4.yaxis.axis_label_text_font_style = "normal"; p4.yaxis.axis_label_text_font_size = "12pt";
p4.yaxis.major_label_text_color='black'
label6=Label(x=210, y=Threshold3, text='V Threshold', text_color='darkblue', background_fill_color='lightgray')
label7=Label(x=210,  y=0, y_units='screen', text='BER='+'{:.2e}'.format(BER3),
                                             text_color='darkblue', background_fill_color='lightgray')
p4.add_layout(label6); p4.add_layout(label7)

bit_label1=Label(x=250, y=320, text='', text_color='red', text_align='center', text_font_size='14pt',
               background_fill_color='lightgray', x_units='data', y_units='screen')
bit_label2=Label(x=600, y=320, text='', text_color='red', text_align='center', text_font_size='14pt',
               background_fill_color='lightgray', x_units='data', y_units='screen')
bit_label3=Label(x=950, y=320, text='', text_color='red', text_align='center', text_font_size='14pt',
               background_fill_color='lightgray', x_units='data', y_units='screen')
p4.add_layout(bit_label1); p4.add_layout(bit_label2); p4.add_layout(bit_label3)

fig_handle3 = show(p4, notebook_handle=True)

count = 0
def update_plot(self):
    global count
    ran_int1 = np.random.randint(0, 2)
    ran_int2 = np.random.randint(0, 2)
    ran_int3 = np.random.randint(0, 2)
    bit_label1.text=str(ran_int1)
    bit_label2.text=str(ran_int2)
    bit_label3.text=str(ran_int3)
    v13 = np.random.normal(ran_int1*Pave3*2*R*RL*G, sigmaT*RL, 400)
    v23 = np.random.normal(ran_int2*Pave3*2*R*RL*G, sigmaT*RL, 400)
    v33 = np.random.normal(ran_int3*Pave3*2*R*RL*G, sigmaT*RL, 400)
    v32 = np.concatenate([v13,v23,v33])
    shift = int(np.random.normal(jitter_value))
    v32=np.roll(v32,int(shift))
    sig_fft= np.fft.rfft(v32)
    fft_freq = np.linspace(0,600/1.200,601)
    filter=np.heaviside(bandwidth3-fft_freq,1)
    sig_fft_f = sig_fft*filter
    vf3=np.fft.irfft(sig_fft_f)
    eyes[count].visible=True
    eyes[count].data_source.data['x']=t
    eyes[count].data_source.data['y']=vf3

    QQ = (2*30e-6*R*G)/(sigmaT+sigmaT)*10**0.5; # label.text='Q-Factor='+ str(Q)[:3]
    BERR = 0.5*special.erfc(QQ/np.sqrt(2))
    label7.text='BER='+'{:.2e}'.format(BERR)

    if count == 20:
        count = 0
    else:
        count += 1
    push_notebook(handle=fig_handle3)

def initialize_plot(self):
    find_parameters()
    thresh_line.data_source.data['y']=zeros+Threshold3
    for eye in eyes:
        eye.visible=False
        eye.data_source.data['y']=zeros
    count = 0
    bit_label1.text=''
    bit_label2.text=''
    bit_label3.text=''
    label6.y=Threshold3
    label7.text='BER='+'{:.2e}'.format(BER3)
    push_notebook(handle=fig_handle3)

initialize_plot(0)
trace_button.on_click(update_plot)
reset_button.on_click(initialize_plot)
# pn.bind(trace_button,update_plot)
# pn.bind(reset_button,initialize_plot)
buttons = pn.Row(trace_button,reset_button)
bplot = pn.pane.Bokeh(p4)
# pn.Column(buttons,bplot)
# buttons
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c4b13ae8-a31b-4283-b539-8a284c5138d0">Loading BokehJS ...</span>
#     </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# ...
